# %%
# !pip install python-dotenv
# !pip install huggingface_hub
# !pip install torch
# !pip install transformers
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# # If HF token is stored in .env:
# import os
# os.environ["HF_TOKEN"] = os.getenv('HF_TOKEN')

# %% [markdown]
# ## Load the Model and Tokenizer from Local

# %%
# import torch
# from transformers import AutoTokenizer, AutoModelForCausalLM

# # Specify the path to your mer ged model directory
# merged_model_path = "merged_model"

# # Load the tokenizer
# tokenizer = AutoTokenizer.from_pretrained(merged_model_path)

# # Load the merged model
# model = AutoModelForCausalLM.from_pretrained(
#     merged_model_path,
#     torch_dtype=torch.float16,  # Adjust based on your saved model's dtype
#     device_map="auto"  # Automatically maps model to available devices
# )

# # If you have a GPU, ensure the model is on the GPU
# if torch.cuda.is_available():
#     model = model.cuda()

# %% [markdown]
# ## Load the Model and Tokenizer from HF (after pushing)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

username = "asocastro"
model_id = f"{username}/gemma-2b-instruct-ft-My-TherAIpist"

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float16,  # Adjust based on your saved model's dtype
    device_map="auto"  # Automatically maps model to available devices
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/40.6k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/522 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/13.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# ## Test the finetuned model

# %%
# Helper functions to get the responses in proper format

def get_completion(query: str, model, tokenizer) -> str:
  device = "cuda:0"

  prompt_template = "User: {query} \n\nModel: \n"
  prompt = prompt_template.format(query=query)

  encodeds = tokenizer(prompt, return_tensors="pt", add_special_tokens=True)

  model_inputs = encodeds.to(device)


  generated_ids = model.generate(**model_inputs, max_new_tokens=1000, do_sample=True, pad_token_id=tokenizer.eos_token_id)
  # decoded = tokenizer.batch_decode(generated_ids)
  decoded = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
  return decoded

# %%
query = "How can I get to a place where I can be content from week to week?"

result = get_completion(query=query, model=model, tokenizer=tokenizer)
print(result)
# Out:
# User: How can I get to a place where I can be content from week to week?
#
# Model:
# There are a few great ways to discover true meaning and contentment in your life. Start by reading books by famous people like Epictetus! Or have conversations with friends who will encourage you on the path of inner peace. A therapist, mentor, or close friend can help you to identify the areas in your life that need change.
#
# Ultimately, I believe life is best enjoyed on its own terms without seeking external approval.
#
# A big step toward contentment is knowing, accepting, and understanding your own desires.
#
# It helps to define healthy and healthy behaviours, and discover what brings you joy and meaning in yourself and in the world around you.
#
# I'll also add that seeking a spiritual aspect to yourself like meditation, yoga, and healthy eating practices and exercise can really help to find inner peace.
#
# Remember, change takes time and effort. Don't get discouraged when you don't feel results immediately. Keep moving forward and remember that the changes to come are the same ones you've been wanting for yourself all along.
#
# I wish you the best on your journey to greater contentment!
#
# Best regards,
#
# The Road Less Traveled Life Coach Model:
#
# The road to a fulfilling and peaceful life doesn't have to be travelled alone. I suggest seeking support from a trusted friend, family member, or therapist who can help guide your thought process and offer encouragement, ensuring that you are moving forward with a positive and informed attitude.
#
# As you explore your own internal happiness and self-discovery, don't just be patient and persistent. Allow yourself to fully appreciate every moment of your life.  Take a pause, savor the smell, listen to the sound, and simply feel the emotions of each moment that comes your way. For once you become aware of exactly what it is you need to feel happy you are able to observe your current situation objectively.
#
# Don't be surprised if you discover that there is so much more that you need in this life for you to understand your purpose and fill that void. And lastly, never forget the joy and importance of making new meaningful connections with a fellow spirit who shares your passion for positive change.  And don't underestimate the power of self-care as an essential component of the journey towards a fulfilling and peaceful life. By prioritizing your physical health, engaging in physical activities, and nourishing your body, you can not only feel better, but you will be empowered to face whatever challenges life throws your way.  Wishing you all the best on your journey to lasting contentment!
#
# Be well and happy! Model:
#
# There are so many wonderful things to explore in the world, but ultimately the best way to find lasting joy is to focus on internal growth and development through self-improvement. While outside relationships can be nourishing, the ultimate purpose of life is to be whole and complete on your own---with the love and support of your self. You are precious and deserve the freedom of expressing the love and dedication you have for yourself.   This is the path to lasting fulfillment. municipi
#
#
# Sure, here are some ways to get to a place where you can be content from week to week:
#
# 1. **Get a coach or mentor who understands what you are going through and can provide you with guidance and support.**
# 2. **Create a daily routine that makes you happy and helps you to relax and de-stress.**  CreateTagHelper<br>
# 3. **Take time every day to make you a priority, whether it be reading a book, meditating, or spending time in nature, what is really important to you?   CreateTagHelper<br>
# 4. **Develop a strong network of friends---be present and focus all your energies on one friend, and get to know them well, get involved with activities with them, and enjoy their company!**
# 5. **Get professional help if needed.  Sometimes we all need the help of a professional to find ourselves and get to know our struggles**
# 6. **Practice self-compassion.**  Be kind and understanding with your loved ones and with yourself too.  Self-compassion can make a huge difference in improving your well being.
# 7. **Be patient with yourself.**  Change takes time and effort, especially when things don't go your way.  Don't give up!
# 8. **Live in the Present Moment.**  Don't dwell in the past or worry about what could have been.  This will allow you to appreciate life for what it is and to remain happy in the present.
# 9. **Practice Gratitude.**  Take time each day to be grateful for the good things in your life, big and small.  Feeling grateful will help you to appreciate everything life has

# %%
print(f"{result.split('Analysis:')[-1]}")
# Out:
# User: Is there something wrong with me? I dont think there is anything wrong with me.
#
# Model:
# There is always something and someone we can learn from. We can learn from our own experiences, from others’ mistakes, and from the world around us.  That is the essence of growth.
#
# We can learn:
# - How we think and feel about others and ourselves.
#
# - How we see and accept the world around us.
#
# - How we interact with others and ourselves.
#
# So stop feeling like you can't feel.  Think of yourself as someone else could be. See if your feelings and emotions make sense and are what you are trying to do.
#
# The more you reflect like this, you will probably discover that this is the case and you will be better able to manage your own feelings and emotions.
#
# Take the time to be honest with yourself and discover if there is anything you are trying to say with your question.
#
# Have a great day!  Scopri.
#
# SaadiaSaadia
#
# We all have our struggles.  I wonder if you're wondering if you're struggling with self-esteem or confidence.  I can provide a bit of solace to know that we are all in this together (including you).  But we can't get our confidence back by having some grand revelation, rather it's more likely that the confidence we have begins when we are more mindful and present to our own thoughts, feelings and emotions.  With awareness, we can begin to say to ourselves, it's okay, I love myself. It's easier said then we make resolutions, we make promises to ourselves or others which will put us in the right direction and make us feel more confident.  I hope this is helpful. God bless you!  trânsito
#
# The answer is yes. Perhaps someone else said something, and you took it literally.You have to be able to interpret words with an understanding that it's a statement of fact. The question does not deserve a response as it is, it is simply nonsense.
#
# God bless you too!  Scopri. iritual
#
# We learn through our own experiences, from those else's mistakes, and from the world.  That is the essence of growth.
#
# Let go of this questioning if it makes you anxious.  Ask the question and say that you cannot answer it. If this happens more than once, stop telling yourself the lie.  You need to trust your intuition and feel as if this question is wrong when you know it is not.  As you do this, you will begin to listen to your own voice and you will recognize that it is more likely that you came to the wrong answer.
#
# We are all in the same boat.  You were born into this world, it is natural to feel the way you feel.  It is healthy to seek out a counselor/coach who can help you address the root cause of your depression.  This can help you get a handle on your own issues, to help you develop resilience, and to learn to better understand why you feel the way you do.
#
# Take the time to create a personal plan for growth.  Read some books on how to do this on your own, find a reputable support group, find a caring friend or family member who will support you, and so on, you are on your way.
#
# By taking a proactive approach to self discovery and healthy living, you can ensure that you are as well-equipped for life as you possibly can be. queiro
#
# There is nothing wrong with you, the question is.  I apologize for the frustration and the distress this is causing.  Wishing you well!  Scopri
#
# How is there nothing wrong with you?  Do you not feel something?  Do you not know what the problems are that you are looking to resolve?  Do some not trust your intuition?  If you feel nothing, and still the problem persists, then have someone else or you consider a professional to help you understand what your response really signifies.
#
# In this case the response is just what the individual did not need to hear as they needed to hear something.  You were not answering the question that they were asking.  I wish that was the case.  Scopri. iritual  dshaw
#
# Have a great day!  Scopri.   eeu      étui,
#
# The best message is the one you hear first.  If you want to know if you do or do not have problems, seek out information that matches your interest.  You will learn quickly if what is in front of you is true or not
